# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot
import mplhep as hep
from scipy.optimize import curve_fit
import json
from pathlib import Path
import os
hep.style.use('CMS')

# Base Directory Creation

try:
    base_dir = Path().resolve().parent
except NameError:
    base_dir = Path(__file__).parent.parent.resolve()

# Subfolders and Gaussian Function for fitting

data_dir = base_dir / 'data'
plots_dir = base_dir / 'plots'
csv_dir = base_dir / 'csvs'
json_dir = base_dir / 'jsons'
simulations_dir = base_dir / 'simulations'
for d in [data_dir, plots_dir, csv_dir, json_dir, simulations_dir]:
    os.makedirs(d, exist_ok = True)
    print(f'Directory created:\n {d}')
print('')
def gaussian(x, a, mean, sigma):
    return a * np.exp(-(x-mean) ** 2/(2*sigma**2))

# Loop over ROOT files

for file_name in os.listdir(data_dir):
    if not file_name.endswith('.root'):
        continue
    file_path = os.path.join(data_dir, file_name)
    print(f'The file {file_name} is being processed.')
    
    try:

        # Extract histogram from ROOT file and Fit Gaussian
        
        file = uproot.open(file_path)
        hist = file['demo/massZto2muon']
        counts, edges = hist.to_numpy()
        bin_centers = (edges[:-1] + edges[1:]) / 2
        print(f'The histogram is loaded successfully from file {file_name}, bins = {len(bin_centers)}')
        popt, _ = curve_fit(gaussian, bin_centers, counts, p0 = [max(counts), 91, 2])
        a, mean, sigma = popt
        print(f'Fit Successful: Mean = {mean:.3f}, Sigma = {sigma:.3f}, Amplitude = {a:.3f}')

        # Plot histogram and Fit
        
        plt.figure(figsize = (8, 6))
        plt.bar(bin_centers, counts, width = (edges[1] - edges[0]), label = f'{file_name} Histogram')
        plt.plot(bin_centers, gaussian(bin_centers, *popt), "r--", label = f"Gaussian Fit: Mean = {mean:.3f} GeV, Sigma = {sigma:.3f}")
        plt.xlabel('Invariant Mass (GeV)', fontsize = 10, loc = 'center')
        plt.ylabel('Events', fontsize = 10, loc = 'center')
        plt.title(f"Z -> mu+ mu- Invariant Mass Spectrum ({file_name})", fontsize=12, loc='center')
        plt.tick_params(axis = 'both', which = 'major', labelsize = 8)
        hep.cms.text('', loc = 0, fontsize = 10)
        plt.legend(fontsize = 8, loc='upper left')
        plt.grid(alpha = 0.3)
        plt.tight_layout(pad = 0.2)
        
        # Save Outputs
        
        plot_file = plots_dir / f"{file_name.replace('.root','')}_massZto2muon.png"
        plt.savefig(plot_file, dpi=300)
        plt.close()
        csv_file = csv_dir / f"{file_name.replace('.root','')}_massZto2muon.csv"
        np.savetxt(csv_file, np.column_stack([bin_centers, counts]), delimiter=",", header="Mass(GeV),Counts", comments='')
        json_file = json_dir / f"{file_name.replace('.root','')}_massZto2muon.json"
        with open(json_file, "w") as f:
            json.dump({"a": a, "mean": mean, "sigma": sigma}, f, indent=4) 
        print(f'[SAVED] Plot Graph: {plot_file}')
        print(f'[SAVED] CSV Histogram: {csv_file}')
        print(f'[SAVED] JSON Fit: {json_file}\n')
        
    except Exception as e:
        print(f'[ERROR] File {file_name} could not be processed. : {e}')
# Out:
# Directory created:
#  C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\data
# Directory created:
#  C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots
# Directory created:
#  C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs
# Directory created:
#  C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons
# Directory created:
#  C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\simulations
#
# The file DoubleMu11.root is being processed.
# The histogram is loaded successfully from file DoubleMu11.root, bins = 120
# Fit Successful: Mean = 90.777, Sigma = 2.314, Amplitude = 94068.978
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\DoubleMu11_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\DoubleMu11_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\DoubleMu11_massZto2muon.json
#
# The file DoubleMu12.root is being processed.
# The histogram is loaded successfully from file DoubleMu12.root, bins = 120
# Fit Successful: Mean = 90.764, Sigma = 2.424, Amplitude = 520447.706
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\DoubleMu12_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\DoubleMu12_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\DoubleMu12_massZto2muon.json
#
# The file DY1011.root is being processed.
# The histogram is loaded successfully from file DY1011.root, bins = 120
# Fit Successful: Mean = 91.000, Sigma = 2.000, Amplitude = -0.010
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\DY1011_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\DY1011_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\DY1011_massZto2muon.json
#
# The file DY1012.root is being processed.
# The histogram is loaded successfully from file DY1012.root, bins = 120
# Fit Successful: Mean = 42.558, Sigma = 4.936, Amplitude = 3895.959
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\DY1012_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\DY1012_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\DY1012_massZto2muon.json
#
# The file HZZ11.root is being processed.
# The histogram is loaded successfully from file HZZ11.root, bins = 120
# Fit Successful: Mean = 90.449, Sigma = 2.340, Amplitude = 5050.253
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\HZZ11_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\HZZ11_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\HZZ11_massZto2muon.json
#
# The file HZZ12.root is being processed.
# The histogram is loaded successfully from file HZZ12.root, bins = 120
# Fit Successful: Mean = 90.522, Sigma = 2.387, Amplitude = 4766.962
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\HZZ12_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\HZZ12_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\HZZ12_massZto2muon.json
#
# The file TTBar11.root is being processed.
# The histogram is loaded successfully from file TTBar11.root, bins = 120
# Fit Successful: Mean = 45.553, Sigma = 60.347, Amplitude = 5337.076
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\TTBar11_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\TTBar11_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\TTBar11_massZto2muon.json
#
# The file TTBar12.root is being processed.
# The histogram is loaded successfully from file TTBar12.root, bins = 120
# Fit Successful: Mean = 48.198, Sigma = 58.179, Amplitude = 391.450
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\TTBar12_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\TTBar12_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\TTBar12_massZto2muon.json
#
# The file ZZ4e11.root is being processed.
# The histogram is loaded successfully from file ZZ4e11.root, bins = 120
# Fit Successful: Mean = 91.000, Sigma = 2.000, Amplitude = 0.000
# C:\Users\Zohaib Hassan\AppData\Local\Temp\ipykernel_7056\3808569204.py:49: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(gaussian, bin_centers, counts, p0 = [max(counts), 91, 2])
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\ZZ4e11_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\ZZ4e11_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\ZZ4e11_massZto2muon.json
#
# The file ZZ4e12.root is being processed.
# The histogram is loaded successfully from file ZZ4e12.root, bins = 120
# Fit Successful: Mean = 91.000, Sigma = 2.000, Amplitude = 0.000
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\ZZ4e12_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\ZZ4e12_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\ZZ4e12_massZto2muon.json
#
# The file ZZ4mu11.root is being processed.
# The histogram is loaded successfully from file ZZ4mu11.root, bins = 120
# Fit Successful: Mean = 76.521, Sigma = 17.186, Amplitude = 7610.593
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\ZZ4mu11_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\ZZ4mu11_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\ZZ4mu11_massZto2muon.json
#
# The file ZZ4mu12.root is being processed.
# The histogram is loaded successfully from file ZZ4mu12.root, bins = 120
# Fit Successful: Mean = 76.790, Sigma = 17.135, Amplitude = 7632.208
# [SAVED] Plot Graph: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\plots\ZZ4mu12_massZto2muon.png
# [SAVED] CSV Histogram: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\csvs\ZZ4mu12_massZto2muon.csv
# [SAVED] JSON Fit: C:\Users\Zohaib Hassan\Downloads\Projects\CERN_Open_Data_Analysis\jsons\ZZ4mu12_massZto2muon.json
